# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
 
image=cv2.imread("gems.jpeg")
m = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
plt.imshow(m,cmap='gray')
##kernel = (1 / 9) * np.ones((3, 3))
m.shape
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-6fefeab75aba> in <module>
#       4
#       5 image=cv2.imread("gems.jpeg")
# ----> 6 m = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
#       7 plt.imshow(m,cmap='gray')
#       8 ##kernel = (1 / 9) * np.ones((3, 3))
#
# error: OpenCV(4.5.1) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-kh7iq4w7\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
ksize=5
kernel = (1 / 9) * np.ones((ksize, ksize))
imagewidth,imageheight=m.shape
paddingheight,paddingwidth=(kernel.shape[0]//2),(kernel.shape[1]//2)
pad=np.zeros((imagewidth+(paddingheight*2), imageheight+(paddingwidth*2)))
pad.shape
plt.imshow(pad)

# %%
pad.shape
# Out:
# (906, 1206)

# %%
pad[paddingwidth:paddingwidth+imagewidth,paddingheight:paddingheight+imageheight]=m
output=np.zeros((imagewidth,imageheight))

# %%
plt.imshow(pad,cmap='gray')

# %%
for row in range(imagewidth):
    for col in range(imageheight):
        output[row,col]=np.sum(pad[row:row+ksize,col:col+ksize]*kernel)

# %%
plt.imshow(output,cmap='gray')
output
# Out:
# array([[338.88888889, 425.88888889, 514.11111111, ..., 317.22222222,
#         261.22222222, 208.22222222],
#        [423.        , 531.66666667, 641.88888889, ..., 399.44444444,
#         328.44444444, 261.33333333],
#        [505.88888889, 636.11111111, 768.22222222, ..., 482.22222222,
#         396.11111111, 314.77777778],
#        ...,
#        [348.66666667, 432.        , 514.22222222, ..., 389.22222222,
#         326.55555556, 262.        ],
#        [294.55555556, 364.88888889, 434.11111111, ..., 316.55555556,
#         265.88888889, 213.66666667],
#        [238.66666667, 295.66666667, 351.66666667, ..., 247.22222222,
#         207.88888889, 167.33333333]])
